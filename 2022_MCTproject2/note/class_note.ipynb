# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/2022_MCTproject2/blob/main/classnote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
classnote.ipynb

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)
